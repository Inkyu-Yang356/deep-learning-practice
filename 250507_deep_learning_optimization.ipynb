# %% [markdown]
# <a href="https://colab.research.google.com/github/Inkyu-Yang356/deep-learning-practice/blob/main/250507_deep_learning_optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 13장 모델의 성능 검증하기

# %% [markdown]
# ##  1. 데이터의 확인과 예측 실행

# %%
import pandas as pd

# 광물 데이터 로드
# !git clone https://github.com/taehojo/data.git
df = pd.read_csv('./data/sonar3.csv', header=None)
df.head()
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 36 (delta 9), reused 26 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 483.12 KiB | 4.13 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# ...

# %%
df[60].value_counts()  # Target 변수 개수
# Out:
# 60
# 1    111
# 0     97
# Name: count, dtype: int64

# %%
X = df.iloc[:,0:60]  # 독립변수
y = df.iloc[:,60]  # 종속변수

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 모델 설정
model = Sequential()  # 모델 구조
model.add(Dense(24,  input_dim=60, activation='relu'))  # Input Layer (input_dim) + Hidden Layer
model.add(Dense(10, activation='relu'))  # Hidden Layer
model.add(Dense(1, activation='sigmoid'))  # Output Layer (0 or 1)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # 모델 학습 설정

history=model.fit(X, y, epochs=200, batch_size=10)  # 200번 학습 진행
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4517 - loss: 0.7632
# Epoch 2/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5470 - loss: 0.6913
# Epoch 3/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5370 - loss: 0.6824
# Epoch 4/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6089 - loss: 0.6811
# Epoch 5/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6415 - loss: 0.6640
# Epoch 6/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7659 - loss: 0.6415
# Epoch 7/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7224 - loss: 0.6350
# Epoch 8/200
# ...

# %% [markdown]
# ## 3. 학습셋과 테스트셋

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

import pandas as pd

# %%
# 학습셋과 테스트셋 구분
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)  # 학습용, 테스트용 데이터셋 분리 및 Shuffle

# %%
# 모델 설정
model = Sequential()
model.add(Dense(24,  input_dim=60, activation='relu'))  # Input Layer + Hidden Layer
model.add(Dense(10, activation='relu'))  # Hidden Layer
model.add(Dense(1, activation='sigmoid'))  # Output Layer; Binary Classification

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history=model.fit(X_train, y_train, epochs=200, batch_size=10)  # 200번 학습
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4240 - loss: 0.7193
# Epoch 2/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5951 - loss: 0.6884
# Epoch 3/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5032 - loss: 0.7030
# Epoch 4/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5451 - loss: 0.6933
# Epoch 5/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5718 - loss: 0.6710
# Epoch 6/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6197 - loss: 0.6476
# Epoch 7/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6652 - loss: 0.6265
# Epoch 8/200
# ...

# %%
score=model.evaluate(X_test, y_test)  # 모델 평가
print('Test accuracy:', score[1])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8633 - loss: 0.3439
# Test accuracy: 0.8730158805847168

# %% [markdown]
# ## 4. 모델 저장과 재사용

# %%
# 모델 이름과 저장할 위치 지정
model.save('./data/model/my_model.hdf5')  # 상대 경로 저장
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import Sequential, load_model

# %%
# 메모리에서 변수 삭제
del model

# %%
# 모델 reload
model = load_model('./data/model/my_model.hdf5')

score=model.evaluate(X_test, y_test)  # 테스트용 데이터셋으로 평가
print('Test accuracy:', score[1])
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8633 - loss: 0.3439
# Test accuracy: 0.8730158805847168

# %% [markdown]
# ## 5. k겹 교차 검증

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

import pandas as pd

# %%
# fold 설정
k=5
kfold = KFold(n_splits=k, shuffle=True)

acc_score = []

def model_fn():
    model = Sequential()
    model.add(Dense(24, input_dim=60, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

# K겹 교차 검증을 이용해 k번 학습 실행
for train_index , test_index in kfold.split(X):  # for 문 k번 반복. spilt()에 의해 k개의 학습셋, 테스트셋으로 분리
    X_train , X_test = X.iloc[train_index,:], X.iloc[test_index,:]  # 독립변수 데이터셋 분리
    y_train , y_test = y.iloc[train_index], y.iloc[test_index]  # 종속변수 데이터셋 분리

    model = model_fn()
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # 모델 학습 설정
    history=model.fit(X_train, y_train, epochs=200, batch_size=10, verbose=0)  # 모델 학습

    accuracy = model.evaluate(X_test, y_test)[1] # 정확도
    acc_score.append(accuracy)  # k개의 학습 정확도

# k번 실시된 정확도 평균
avg_acc_score = sum(acc_score)/k

# 결과 출력
print('정확도:', acc_score)
print('정확도 평균:', avg_acc_score)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8001 - loss: 0.7006
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8264 - loss: 0.5216
# ...
